# %% [markdown]
# # Import modules

# %%
import tensorflow.keras
import pygad.kerasga
import numpy
import pygad
import pandas as pd
import matplotlib.pyplot as plt

# %%
"""
====Network Bandwidth========
1	0-5 GBps
2	5- 20 GBps
3	20 -50GBps
4	above  50 GBps
	
====User Type====
1	1-100
2	101-1000
3	1-1000
4	Above 1000

====Processor Speed (Per processor)====
1	1GHz-2GHz 
2	2GHz -4GHz
3	Above 4Hz
3	1GHz-4GHz 
	
====Ram====
1	16-32GB
2	32-64GB
3	Above 64GB
4	16-64GB
	
====vCPUs====
1	2 to 12
2	12 to 20
3	20  to 32
4	12 to 32

====OutPut====
1	St1.Nano
2	Mt2.GP
3	Lt3.Large
4	Lt4.Xlarge
5	Mt5.Prem

"""
# Out:
# '\n====Network Bandwidth========\n1\t0-5 GBps\n2\t5- 20 GBps\n3\t20 -50GBps\n4\tabove  50 GBps\n\t\n====User Type====\n1\t1-100\n2\t101-1000\n3\t1-1000\n4\tAbove 1000\n\n====Processor Speed (Per processor)====\n1\t1GHz-2GHz \n2\t2GHz -4GHz\n3\tAbove 4Hz\n3\t1GHz-4GHz \n\t\n====Ram====\n1\t16-32GB\n2\t32-64GB\n3\tAbove 64GB\n4\t16-64GB\n\t\n====vCPUs====\n1\t2 to 12\n2\t12 to 20\n3\t20  to 32\n4\t12 to 32\n\n====OutPut====\n1\tSt1.Nano\n2\tMt2.GP\n3\tLt3.Large\n4\tLt4.Xlarge\n5\tMt5.Prem\n\n'

# %% [markdown]
# # Model Training

# %%
def fitness_func(solution, sol_idx):
    global data_inputs, data_outputs, keras_ga, model

    model_weights_matrix = pygad.kerasga.model_weights_as_matrix(model=model,
                                                                 weights_vector=solution)

    model.set_weights(weights=model_weights_matrix)

    predictions = model.predict(data_inputs)

    mae = tensorflow.keras.losses.MeanAbsoluteError()
    error = mae(data_outputs, predictions).numpy()

    solution_fitness = 1.0 / (error + 0.00000001)

    return solution_fitness

def on_generation(ga_instance):
    print("Generation = {generation}".format(generation=ga_instance.generations_completed))
    print("Fitness    = {fitness}".format(fitness=ga_instance.best_solution(ga_instance.last_generation_fitness)[1]), end='\n\n')

# %%
input_layer  = tensorflow.keras.layers.Input(5)
dense_layer1 = tensorflow.keras.layers.Dense(10, activation="relu")(input_layer)
output_layer = tensorflow.keras.layers.Dense(1, activation="linear")(dense_layer1)

model = tensorflow.keras.Model(inputs=input_layer, outputs=output_layer)

weights_vector = pygad.kerasga.model_weights_as_vector(model=model)

keras_ga = pygad.kerasga.KerasGA(model=model,
                                 num_solutions=10)

# Data inputs
data_inputs = numpy.array([[1, 1, 1, 1, 1],
                           [3, 2, 2, 2, 2],
                           [4, 3, 2, 3, 3],
                           [4, 4, 3, 3, 4],
                           [4, 1, 4, 4, 4]])

# Data outputs
data_outputs = numpy.array([[1],
                            [2],
                            [3],
                            [4],
                            [5]])

ga_instance = pygad.GA(num_generations=250, 
                       num_parents_mating=5, 
                       fitness_func=fitness_func,
                       initial_population=keras_ga.population_weights,
                       on_generation=on_generation,
                       suppress_warnings=True)
ga_instance.run()
# Out:
# Generation = 1
# Fitness    = 1.2165490156932546
#
# Generation = 2
# Fitness    = 3.832918113165483
#
# Generation = 3
# Fitness    = 3.832918113165483
#
# Generation = 4
# Fitness    = 3.832918113165483
#
# Generation = 5
# Fitness    = 3.832918113165483
#
# Generation = 6
# Fitness    = 3.832918113165483
#
# Generation = 7
# Fitness    = 3.832918113165483
#
# Generation = 8
# Fitness    = 3.832918113165483
#
# Generation = 9
# Fitness    = 3.832918113165483
#
# Generation = 10
# Fitness    = 3.832918113165483
#
# Generation = 11
# Fitness    = 3.832918113165483
#
# Generation = 12
# Fitness    = 3.832918113165483
#
# Generation = 13
# Fitness    = 3.832918113165483
#
# Generation = 14
# Fitness    = 3.832918113165483
#
# Generation = 15
# Fitness    = 3.832918113165483
#
# Generation = 16
# Fitness    = 3.832918113165483
#
# Generation = 17
# Fitness    = 3.832918113165483
#
# Generation = 18
# Fitness    = 3.832918113165483
#
# Generation = 19
# Fitness    = 4.290464663784054
#
# Generation = 20
# Fitness    = 4.290464663784054
#
# Generation = 21
# Fitness    = 4.290464663784054
#
# Generation = 22
# Fitness    = 5.492772090928902
#
# Generation = 23
# Fitness    = 5.492772090928902
#
# Generation = 24
# Fitness    = 5.902865734628461
#
# Generation = 25
# Fitness    = 5.902865734628461
#
# Generation = 26
# Fitness    = 5.902865734628461
#
# Generation = 27
# Fitness    = 5.902865734628461
#
# Generation = 28
# Fitness    = 5.902865734628461
#
# Generation = 29
# Fitness    = 5.902865734628461
#
# Generation = 30
# Fitness    = 5.902865734628461
#
# Generation = 31
# Fitness    = 5.902865734628461
#
# Generation = 32
# Fitness    = 5.902865734628461
#
# Generation = 33
# Fitness    = 5.902865734628461
#
# Generation = 34
# Fitness    = 7.056258744465608
#
# Generation = 35
# Fitness    = 7.056258744465608
#
# Generation = 36
# Fitness    = 7.056258744465608
#
# Generation = 37
# Fitness    = 7.056258744465608
#
# Generation = 38
# Fitness    = 7.056258744465608
#
# Generation = 39
# Fitness    = 7.056258744465608
#
# Generation = 40
# Fitness    = 7.056258744465608
#
# Generation = 41
# Fitness    = 7.056258744465608
#
# Generation = 42
# Fitness    = 10.274112211131934
#
# Generation = 43
# Fitness    = 10.274112211131934
#
# Generation = 44
# Fitness    = 10.274112211131934
#
# Generation = 45
# Fitness    = 10.274112211131934
#
# Generation = 46
# Fitness    = 10.274112211131934
#
# Generation = 47
# Fitness    = 10.274112211131934
#
# Generation = 48
# Fitness    = 10.274112211131934
#
# Generation = 49
# Fitness    = 10.274112211131934
#
# Generation = 50
# Fitness    = 10.274112211131934
#
# Generation = 51
# Fitness    = 10.274112211131934
#
# Generation = 52
# Fitness    = 10.274112211131934
#
# Generation = 53
# Fitness    = 10.274112211131934
#
# Generation = 54
# Fitness    = 10.274112211131934
#
# Generation = 55
# Fitness    = 10.274112211131934
#
# Generation = 56
# Fitness    = 10.274112211131934
#
# Generation = 57
# Fitness    = 10.274112211131934
#
# Generation = 58
# Fitness    = 10.274112211131934
#
# Generation = 59
# Fitness    = 10.274112211131934
#
# Generation = 60
# Fitness    = 10.274112211131934
#
# Generation = 61
# Fitness    = 10.274112211131934
#
# Generation = 62
# Fitness    = 10.274112211131934
#
# Generation = 63
# Fitness    = 10.274112211131934
#
# Generation = 64
# Fitness    = 10.274112211131934
#
# Generation = 65
# Fitness    = 10.274112211131934
#
# Generation = 66
# Fitness    = 10.274112211131934
#
# Generation = 67
# Fitness    = 10.274112211131934
#
# Generation = 68
# Fitness    = 10.274112211131934
#
# Generation = 69
# Fitness    = 10.274112211131934
#
# Generation = 70
# Fitness    = 10.274112211131934
#
# Generation = 71
# Fitness    = 10.274112211131934
#
# Generation = 72
# Fitness    = 10.274112211131934
#
# Generation = 73
# Fitness    = 10.274112211131934
#
# Generation = 74
# Fitness    = 10.274112211131934
#
# Generation = 75
# Fitness    = 10.274112211131934
#
# Generation = 76
# Fitness    = 10.274112211131934
#
# Generation = 77
# Fitness    = 10.274112211131934
#
# Generation = 78
# Fitness    = 10.274112211131934
#
# Generation = 79
# Fitness    = 10.274112211131934
#
# Generation = 80
# Fitness    = 10.274112211131934
#
# Generation = 81
# Fitness    = 10.274112211131934
#
# Generation = 82
# Fitness    = 10.274112211131934
#
# Generation = 83
# Fitness    = 10.274112211131934
#
# Generation = 84
# Fitness    = 10.274112211131934
#
# Generation = 85
# Fitness    = 10.274112211131934
#
# Generation = 86
# Fitness    = 10.274112211131934
#
# Generation = 87
# Fitness    = 10.274112211131934
#
# Generation = 88
# Fitness    = 10.274112211131934
#
# Generation = 89
# Fitness    = 10.274112211131934
#
# Generation = 90
# Fitness    = 10.274112211131934
#
# Generation = 91
# Fitness    = 10.274112211131934
#
# Generation = 92
# Fitness    = 10.274112211131934
#
# Generation = 93
# Fitness    = 10.274112211131934
#
# Generation = 94
# Fitness    = 10.274112211131934
#
# Generation = 95
# Fitness    = 10.274112211131934
#
# Generation = 96
# Fitness    = 10.274112211131934
#
# Generation = 97
# Fitness    = 10.274112211131934
#
# Generation = 98
# Fitness    = 10.274112211131934
#
# Generation = 99
# Fitness    = 10.274112211131934
#
# Generation = 100
# Fitness    = 10.274112211131934
#
# Generation = 101
# Fitness    = 10.274112211131934
#
# Generation = 102
# Fitness    = 10.274112211131934
#
# Generation = 103
# Fitness    = 10.274112211131934
#
# Generation = 104
# Fitness    = 10.274112211131934
#
# Generation = 105
# Fitness    = 10.274112211131934
#
# Generation = 106
# Fitness    = 10.274112211131934
#
# Generation = 107
# Fitness    = 10.274112211131934
#
# Generation = 108
# Fitness    = 10.274112211131934
#
# Generation = 109
# Fitness    = 10.274112211131934
#
# Generation = 110
# Fitness    = 10.274112211131934
#
# Generation = 111
# Fitness    = 10.739556406485084
#
# Generation = 112
# Fitness    = 10.739556406485084
#
# Generation = 113
# Fitness    = 10.739556406485084
#
# Generation = 114
# Fitness    = 10.739556406485084
#
# Generation = 115
# Fitness    = 10.739556406485084
#
# Generation = 116
# Fitness    = 10.739556406485084
#
# Generation = 117
# Fitness    = 10.739556406485084
#
# Generation = 118
# Fitness    = 10.739556406485084
#
# Generation = 119
# Fitness    = 10.739556406485084
#
# Generation = 120
# Fitness    = 10.739556406485084
#
# Generation = 121
# Fitness    = 10.739556406485084
#
# Generation = 122
# Fitness    = 10.739556406485084
#
# Generation = 123
# Fitness    = 10.739556406485084
#
# Generation = 124
# Fitness    = 10.739556406485084
#
# Generation = 125
# Fitness    = 10.739556406485084
#
# Generation = 126
# Fitness    = 10.739556406485084
#
# Generation = 127
# Fitness    = 10.739556406485084
#
# Generation = 128
# Fitness    = 10.739556406485084
#
# Generation = 129
# Fitness    = 10.739556406485084
#
# Generation = 130
# Fitness    = 10.739556406485084
#
# Generation = 131
# Fitness    = 10.739556406485084
#
# Generation = 132
# Fitness    = 10.739556406485084
#
# Generation = 133
# Fitness    = 10.739556406485084
#
# Generation = 134
# Fitness    = 10.739556406485084
#
# Generation = 135
# Fitness    = 10.739556406485084
#
# Generation = 136
# Fitness    = 10.739556406485084
#
# Generation = 137
# Fitness    = 10.739556406485084
#
# Generation = 138
# Fitness    = 10.739556406485084
#
# Generation = 139
# Fitness    = 10.739556406485084
#
# Generation = 140
# Fitness    = 10.739556406485084
#
# Generation = 141
# Fitness    = 10.739556406485084
#
# Generation = 142
# Fitness    = 10.739556406485084
#
# Generation = 143
# Fitness    = 10.739556406485084
#
# Generation = 144
# Fitness    = 10.739556406485084
#
# Generation = 145
# Fitness    = 10.739556406485084
#
# Generation = 146
# Fitness    = 10.739556406485084
#
# Generation = 147
# Fitness    = 10.739556406485084
#
# Generation = 148
# Fitness    = 10.739556406485084
#
# Generation = 149
# Fitness    = 10.739556406485084
#
# Generation = 150
# Fitness    = 10.739556406485084
#
# Generation = 151
# Fitness    = 10.739556406485084
#
# Generation = 152
# Fitness    = 10.739556406485084
#
# Generation = 153
# Fitness    = 10.739556406485084
#
# Generation = 154
# Fitness    = 10.739556406485084
#
# Generation = 155
# Fitness    = 10.739556406485084
#
# Generation = 156
# Fitness    = 10.739556406485084
#
# Generation = 157
# Fitness    = 10.739556406485084
#
# Generation = 158
# Fitness    = 10.739556406485084
#
# Generation = 159
# Fitness    = 10.739556406485084
#
# Generation = 160
# Fitness    = 10.739556406485084
#
# Generation = 161
# Fitness    = 10.739556406485084
#
# Generation = 162
# Fitness    = 10.739556406485084
#
# Generation = 163
# Fitness    = 10.739556406485084
#
# Generation = 164
# Fitness    = 10.739556406485084
#
# Generation = 165
# Fitness    = 10.739556406485084
#
# Generation = 166
# Fitness    = 11.38613717295138
#
# Generation = 167
# Fitness    = 11.38613717295138
# Generation = 168
# Fitness    = 11.38613717295138
#
# Generation = 169
# Fitness    = 11.38613717295138
#
# Generation = 170
# Fitness    = 11.38613717295138
#
# Generation = 171
# Fitness    = 11.38613717295138
#
# Generation = 172
# Fitness    = 11.38613717295138
#
# Generation = 173
# Fitness    = 11.38613717295138
#
# Generation = 174
# Fitness    = 11.38613717295138
#
# Generation = 175
# Fitness    = 11.38613717295138
#
# Generation = 176
# Fitness    = 11.38613717295138
#
# Generation = 177
# Fitness    = 11.38613717295138
#
# Generation = 178
# Fitness    = 11.38613717295138
#
# Generation = 179
# Fitness    = 11.38613717295138
#
# Generation = 180
# Fitness    = 11.38613717295138
#
# Generation = 181
# Fitness    = 11.38613717295138
#
# Generation = 182
# Fitness    = 11.38613717295138
#
# Generation = 183
# Fitness    = 11.38613717295138
#
# Generation = 184
# Fitness    = 11.38613717295138
#
# Generation = 185
# Fitness    = 11.38613717295138
#
# Generation = 186
# Fitness    = 11.38613717295138
#
# Generation = 187
# Fitness    = 11.38613717295138
#
# Generation = 188
# Fitness    = 11.38613717295138
#
# Generation = 189
# Fitness    = 11.38613717295138
#
# Generation = 190
# Fitness    = 11.38613717295138
#
# Generation = 191
# Fitness    = 11.38613717295138
#
# Generation = 192
# Fitness    = 11.38613717295138
#
# Generation = 193
# Fitness    = 11.38613717295138
#
# Generation = 194
# Fitness    = 11.38613717295138
#
# Generation = 195
# Fitness    = 11.38613717295138
#
# Generation = 196
# Fitness    = 11.38613717295138
#
# Generation = 197
# Fitness    = 11.38613717295138
#
# Generation = 198
# Fitness    = 11.38613717295138
#
# Generation = 199
# Fitness    = 11.38613717295138
#
# Generation = 200
# Fitness    = 11.38613717295138
#
# Generation = 201
# Fitness    = 11.38613717295138
#
# Generation = 202
# Fitness    = 11.38613717295138
#
# Generation = 203
# Fitness    = 11.38613717295138
#
# Generation = 204
# Fitness    = 11.38613717295138
#
# Generation = 205
# Fitness    = 11.38613717295138
#
# Generation = 206
# Fitness    = 11.38613717295138
#
# Generation = 207
# Fitness    = 11.38613717295138
#
# Generation = 208
# Fitness    = 13.703799260630758
#
# Generation = 209
# Fitness    = 13.703799260630758
#
# Generation = 210
# Fitness    = 13.703799260630758
#
# Generation = 211
# Fitness    = 13.703799260630758
#
# Generation = 212
# Fitness    = 13.703799260630758
#
# Generation = 213
# Fitness    = 13.703799260630758
#
# Generation = 214
# Fitness    = 13.703799260630758
#
# Generation = 215
# Fitness    = 13.703799260630758
#
# Generation = 216
# Fitness    = 13.703799260630758
#
# Generation = 217
# Fitness    = 13.703799260630758
#
# Generation = 218
# Fitness    = 13.703799260630758
#
# Generation = 219
# Fitness    = 13.703799260630758
#
# Generation = 220
# Fitness    = 13.703799260630758
#
# Generation = 221
# Fitness    = 13.703799260630758
#
# Generation = 222
# Fitness    = 13.703799260630758
#
# Generation = 223
# Fitness    = 13.703799260630758
#
# Generation = 224
# Fitness    = 13.703799260630758
#
# Generation = 225
# Fitness    = 13.703799260630758
#
# Generation = 226
# Fitness    = 13.703799260630758
#
# Generation = 227
# Fitness    = 13.703799260630758
#
# Generation = 228
# Fitness    = 13.703799260630758
#
# Generation = 229
# Fitness    = 13.703799260630758
#
# Generation = 230
# Fitness    = 13.703799260630758
#
# Generation = 231
# Fitness    = 13.703799260630758
#
# Generation = 232
# Fitness    = 13.703799260630758
#
# Generation = 233
# Fitness    = 13.703799260630758
#
# Generation = 234
# Fitness    = 13.703799260630758
#
# Generation = 235
# Fitness    = 13.703799260630758
#
# Generation = 236
# Fitness    = 13.703799260630758
#
# Generation = 237
# Fitness    = 13.703799260630758
#
# Generation = 238
# Fitness    = 13.703799260630758
#
# Generation = 239
# Fitness    = 13.703799260630758
#
# Generation = 240
# Fitness    = 13.703799260630758
#
# Generation = 241
# Fitness    = 13.703799260630758
#
# Generation = 242
# Fitness    = 13.703799260630758
#
# Generation = 243
# Fitness    = 13.703799260630758
#
# Generation = 244
# Fitness    = 13.703799260630758
#
# Generation = 245
# Fitness    = 13.703799260630758
#
# Generation = 246
# Fitness    = 13.703799260630758
#
# Generation = 247
# Fitness    = 13.703799260630758
#
# Generation = 248
# Fitness    = 13.703799260630758
#
# Generation = 249
# Fitness    = 13.703799260630758
#
# Generation = 250
# Fitness    = 13.703799260630758

# %%
# After the generations complete, some plots are showed that summarize how the outputs/fitness values evolve over generations.
fig = ga_instance.plot_result(title="PyGAD & Keras - Iteration vs. Fitness", linewidth=4)

# %%
# Returning the details of the best solution.
solution, solution_fitness, _ = ga_instance.best_solution()
print("Parameters of the best solution:\n{solution}".format(solution=solution), end="\n\n")

# This is equation to the number of trainable parameters in the Keras model.
print("Length of the solution is:", len(solution), end='\n\n')

print("Fitness value of the best solution:\n{solution_fitness}".format(solution_fitness=solution_fitness), end='\n\n')
# Out:
# Parameters of the best solution:
# [-1.69203744 -0.36213754 -1.07806359 -0.56849905  0.0210526   0.66324841
#  -0.32731193 -0.17798229 -0.00271518  0.99509617 -1.53876117 -0.29157525
#  -0.75915492 -0.68141831  0.15245076 -0.22292296  0.99359242 -0.35479811
#  -1.0490977   0.39532087 -0.26348782  0.60863308 -1.55594577  0.49127726
#  -0.46503085  1.17712259 -0.01402208 -1.41672631  1.95082548 -1.00798441
#  -1.15034116  0.44064438 -0.81272549  0.96289632  0.48090148 -0.42899447
#  -1.09648403  0.82553702 -0.8907239  -0.94822833 -0.16579003  1.98854433
#  -0.53011205 -1.74423215  0.31708413  1.24853227 -0.84892398 -1.15663845
#  -0.45760941 -0.47828848 -0.93394354 -1.39336044  0.45564706 -0.07136886
#   0.11207145 -1.75821735  0.03073441  0.75175233 -0.84877174  1.05478658
#   0.59836421  0.17461794  0.36980667  0.26312555  0.22317082  0.2485797
#  -1.71824974  0.38142867  0.98674707 -0.26511023  0.47508959]
#
# Length of the solution is: 71
#
# Fitness value of the best solution:
# 13.703799260630758

# %%
# Fetch the parameters of the best solution.
best_solution_weights = pygad.kerasga.model_weights_as_matrix(model=model,
                                                              weights_vector=solution)
model.set_weights(best_solution_weights)
predictions = model.predict(data_inputs)
print("Predictions:\n", predictions, end='\n\n')

print("Correct Outputs:\n", data_outputs, end='\n\n')

# Correct Outputs vs Predictions plot.
plt.plot(predictions,'--',label="Predictions")
plt.plot(data_outputs,label="Correct Outputs")
plt.title('Correct Outputs vs Predictions')
plt.legend()
plt.show()

mae = tensorflow.keras.losses.MeanAbsoluteError()
abs_error = mae(data_outputs, predictions).numpy()
print("Absolute Error:\n", abs_error)
# Out:
# Predictions:
#  [[0.9520206]
#  [2.1963105]
#  [3.036325 ]
#  [3.9874837]
#  [5.071731 ]]
#
# Correct Outputs:
#  [[1]
#  [2]
#  [3]
#  [4]
#  [5]]
# Absolute Error:
#  0.072972454

# %% [markdown]
# # Create Model File

# %%
def predict_mpg(config, model):
    
    if type(config) == dict:
        df = pd.DataFrame(config)
    else:
        df = config
    
#     print(prepared_df)
    y_pred = model.predict(df)
    return y_pred

# %%
config = {
    'NetworkBandwidth': [1],
    'UserType': [1],
    'ProcessorSpeed': [1],
    'RAM': [1],
    'vCPUs': [1]
}

predictValue = predict_mpg(config, model)

OutPutList=["St1.Nano","Mt2.GP","Lt3.Large","Lt4.Xlarge"]

OutPutList[int(predictValue)]
# Out:
# 'St1.Nano'

# %%
# serialize model to JSON
model_json = model.to_json()
with open("model.json", "w") as json_file:
    json_file.write(model_json)
# serialize weights to HDF5
model.save_weights("model.h5")
print("Saved model to disk")
# Out:
# Saved model to disk

# %%
# load json and create model
json_file = open('model.json', 'r')
loaded_model_json = json_file.read()
json_file.close()
loaded_model = tensorflow.keras.models.model_from_json(loaded_model_json)
# load weights into new model
loaded_model.load_weights("model.h5")
print("Loaded model from disk")
# Out:
# Loaded model from disk

# %%
predictValue = predict_mpg(config, loaded_model)

OutPutList=["St1.Nano","Mt2.GP","Lt3.Large","Lt4.Xlarge"]

OutPutList[int(predictValue)]
# Out:
# 'St1.Nano'
